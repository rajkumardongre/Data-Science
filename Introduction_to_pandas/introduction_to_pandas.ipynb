# %% [markdown]
# # Introduction to pandas

# %%
import pandas as pd

# %% [markdown]
# ## Datatypes

# %% [markdown]
# In Pandas their are 2 types of datatypes
# - Series = 1-dimensional
# - DataFrames = 2-dimensional

# %% [markdown]
# ### Series

# %%
series = pd.Series(["BMW", "Honda", "Audi"])

# %%
series
# Out:
# 0      BMW
# 1    Honda
# 2     Audi
# dtype: object

# %%
colours = pd.Series(["Red", "Black", "Blue"])
colours
# Out:
# 0      Red
# 1    Black
# 2     Blue
# dtype: object

# %% [markdown]
# ### Data Frames

# %%
car_data = pd.DataFrame({"Car Make" : series, "Colour": colours})
car_data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1    Honda  Black
# 2     Audi   Blue

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting CSV
# car_sales.to_csv("exported_car_sales.csv")

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 344.0+ bytes

# %%
car_sales.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3124/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %% [markdown]
# ## Viewing and Selecting Data

# %% [markdown]
# Give top 5 Rows of dataframe, if no argument is passed in head() function

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# Give top 7 rows of Dataframe

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %% [markdown]
# Give Last 5 Rows of dataframe

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ### iLoc & Loc

# %%
animals = pd.Series(["Dog", "Cat", "Lion", "Tiger", "Panda"], index=[1,3,2,3,5])
animals
# Out:
# 1      Dog
# 3      Cat
# 2     Lion
# 3    Tiger
# 5    Panda
# dtype: object

# %% [markdown]
# **Loc[ lOCATION ]** gives element at given location.

# %%
animals.loc[3]
# Out:
# 3      Cat
# 3    Tiger
# dtype: object

# %% [markdown]
# **iLoc[ INDEX ]** gives element at given index

# %%
animals.iloc[1]
# Out:
# 'Cat'

# %%
animals
# Out:
# 1      Dog
# 3      Cat
# 2     Lion
# 3    Tiger
# 5    Panda
# dtype: object

# %% [markdown]
# ### Selection

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# ### crosstab( ) use to cris-cross two column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# ### groupby()

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Make","Colour"]).mean()
# Out:
#                Odometer (KM)  Doors
# Make   Colour
# BMW    Black         11179.0    5.0
# Honda  Blue          50218.0    4.0
#        Red           87899.0    4.0
# Nissan White        122347.5    4.0
# Toyota Blue          32549.0    3.0
#        Green         99213.0    4.0
#        White        105021.5    4.0

# %% [markdown]
# ### visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3124/2312081839.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"]/100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipluting Data

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %% [markdown]
# ### Filling Missing values in a Cloumn

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ### Deleting the missing Rows

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# New Column called Seats
seats_column = pd.Series([5,5,5,5,5])
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %% [markdown]
# ### Creating Column from python List

# %%
fuel_economy = [6.4, 8.6, 9.7, 5.3, 6.0, 2.3, 11.2, 4.2, 5.1, 7.9]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used
# 0         9602.752
# 1         7559.314
# 2         3157.253
# 3          592.487
# 4        12785.700
# 5         2281.899
# 6         5118.176
# 7         2298.996
# ...

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used  Total fuel used (L)
# 0         9602.752             9602.752
# 1         7559.314             7559.314
# 2         3157.253             3157.253
# ...

# %% [markdown]
# ### Create column from single value

# %%
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used  Total fuel used (L)  Number of Wheels
# 0         9602.752             9602.752                 4
# 1         7559.314             7559.314                 4
# ...

# %%
car_sales["Passed Road Saftey"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used  Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0         9602.752             9602.752                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                  float64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used        float64
# Total fuel used (L)    float64
# Number of Wheels         int64
# Passed Road Saftey        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used  Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0         9602.752             9602.752                 4                True
# ...

# %% [markdown]
# ### Deleting a Column (axis=1)

# %%
car_sales = car_sales.drop("Total fuel used", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0             9602.752                 4                True
# 1             7559.314                 4                True
# ...

# %%
car_sales.shape
# Out:
# (10, 10)

# %% [markdown]
# ### Shuffel Rows

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 9  nissan  White          31600      4   9700.0    5.0             7.9
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 8             3060.000                 4                True
# 4            12785.700                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0             9602.752                 4                True
# 1             7559.314                 4                True
# ...

# %%
car_sales_shuffeled = car_sales.sample(frac=1)
car_sales_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 9  nissan  White          31600      4   9700.0    5.0             7.9
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 7             2298.996                 4                True
# 1             7559.314                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0             9602.752                 4                True
# 1             7559.314                 4                True
# ...

# %% [markdown]
# ### Select only 20% of data

# %%
car_sales.sample(frac=0.2)
# Out:
#     Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 6  honda   Blue          45698      4  7500.0    5.0            11.2
# 7  honda   Blue          54738      4  7000.0    5.0             4.2
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 6             5118.176                 4                True
# 7             2298.996                 4                True

# %%
car_sales_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 9  nissan  White          31600      4   9700.0    5.0             7.9
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 7             2298.996                 4                True
# 1             7559.314                 4                True
# ...

# %% [markdown]
# ### Reseting all the index

# %%
car_sales_shuffeled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0   honda   Blue          54738      4   7000.0    5.0             4.2
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  nissan  White          31600      4   9700.0    5.0             7.9
# 3  nissan  White         213095      4   3500.0    5.0             6.0
# 4  toyota  White         150043      4   4000.0    5.0             6.4
# 5     bmw  Black          11179      5  22000.0    5.0             5.3
# 6  toyota   Blue          32549      3   7000.0    5.0             9.7
# 7  toyota  White          60000      4   6250.0    5.0             5.1
# 8  toyota  Green          99213      4   4500.0    5.0             2.3
# 9   honda   Blue          45698      4   7500.0    5.0            11.2
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0             2298.996                 4                True
# 1             7559.314                 4                True
# ...

# %% [markdown]
# ### Apply function to columns

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             6.4
# 1   honda    Red          87899      4   5000.0    5.0             8.6
# 2  toyota   Blue          32549      3   7000.0    5.0             9.7
# 3     bmw  Black          11179      5  22000.0    5.0             5.3
# 4  nissan  White         213095      4   3500.0    5.0             6.0
# 5  toyota  Green          99213      4   4500.0    5.0             2.3
# 6   honda   Blue          45698      4   7500.0    5.0            11.2
# 7   honda   Blue          54738      4   7000.0    5.0             4.2
# 8  toyota  White          60000      4   6250.0    5.0             5.1
# 9  nissan  White          31600      4   9700.0    5.0             7.9
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0             9602.752                 4                True
# 1             7559.314                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x : x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000.0    5.0             6.4
# 1   honda    Red      54936.875      4   5000.0    5.0             8.6
# 2  toyota   Blue      20343.125      3   7000.0    5.0             9.7
# 3     bmw  Black       6986.875      5  22000.0    5.0             5.3
# 4  nissan  White     133184.375      4   3500.0    5.0             6.0
# 5  toyota  Green      62008.125      4   4500.0    5.0             2.3
# 6   honda   Blue      28561.250      4   7500.0    5.0            11.2
# 7   honda   Blue      34211.250      4   7000.0    5.0             4.2
# 8  toyota  White      37500.000      4   6250.0    5.0             5.1
# 9  nissan  White      19750.000      4   9700.0    5.0             7.9
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftey
# 0             9602.752                 4                True
# 1             7559.314                 4                True
# ...
